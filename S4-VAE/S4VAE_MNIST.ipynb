# %%
import matplotlib.pyplot as plt
import numpy as np
import math
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.nn import init
import torchvision
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
from torch.utils.data import sampler
from torch.autograd import Variable
from torch.nn import functional as F
from torchvision import datasets, transforms
from s4d import S4D

device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
# MAKING THE S4 ARCHITECTURE

if tuple(map(int, torch.__version__.split('.')[:2])) == (1, 11):
    print("WARNING: Dropout is bugged in PyTorch 1.11. Results may be worse.")
    dropout_fn = nn.Dropout
if tuple(map(int, torch.__version__.split('.')[:2])) >= (1, 12):
    dropout_fn = nn.Dropout1d
else:
    dropout_fn = nn.Dropout2d



class VAE_SSM(nn.Module):

    def __init__(
        self,
        d_input,
        d_output=10,
        d_model=256,
        n_layers=4,
        dropout=0.2,
        prenorm=False,
    ):
        super().__init__()

        self.prenorm = prenorm

        # Linear encoder (d_input = 1 for grayscale and 3 for RGB)
        self.encoder = nn.Linear(d_input, d_model)

        # Stack S4 layers as residual blocks
        self.s4_layers = nn.ModuleList()
        self.norms = nn.ModuleList()
        self.dropouts = nn.ModuleList()
        for _ in range(n_layers):
            self.s4_layers.append(
                S4D(d_model, dropout=dropout, transposed=True, lr=min(0.001, 0.01))
            )
            self.norms.append(nn.LayerNorm(d_model))
            self.dropouts.append(dropout_fn(dropout))

        # input: (N, d_model) -> output: (N, d_model) : mean_layer
        self.mean_layer = nn.Linear(in_features = d_model, out_features = d_model)

        # input: (N, d_model) -> output: (N, d_model) : logvar_layer
        self.logvar_layer = nn.Linear(in_features = d_model, out_features = d_model)

        # Linear decoder
        self.decoder = nn.Sequential(
            nn.Linear(d_model, d_input),
            nn.Sigmoid())
        #self.channel_reducer = nn.Linear(d_model, 1)
        self.d_output = d_output


    def forward(self, x):
        """
        Input x is shape (B, L, d_input)
        """
        #x /=255 #Normalizing
        x = self.encoder(x)  # (B, L, d_input) -> (B, L, d_model)

        x = x.transpose(-1, -2)  # (B, L, d_model) -> (B, d_model, L)
        #print("X shape",x.shape)
        for layer, norm, dropout in zip(self.s4_layers, self.norms, self.dropouts):
            # Each iteration of this loop will map (B, d_model, L) -> (B, d_model, L)

            z = x
            if self.prenorm:
                # Prenorm
                z = norm(z.transpose(-1, -2)).transpose(-1, -2)

            # Apply S4 block: we ignore the state input and output
            #print(z.shape)
            z, _ = layer(z)

            # Dropout on the output of the S4 block
            z = dropout(z)

            # Residual connection
            x = z + x

            if not self.prenorm:
                # Postnorm
                x = norm(x.transpose(-1, -2)).transpose(-1, -2)

        x = x.transpose(-1, -2)

        # Pooling: average pooling over the sequence length
        #x = x.mean(dim=1)

        encoder_output = x
        mu = self.mean_layer(encoder_output)
        logvar = self.logvar_layer(encoder_output)

        z = self.reparametrize(mu, logvar)

        z = z.transpose(-1, -2)  # (B, L, d_model) -> (B, d_model, L)
        #print("X shape",x.shape)
        for layer, norm, dropout in zip(self.s4_layers, self.norms, self.dropouts):
            # Each iteration of this loop will map (B, d_model, L) -> (B, d_model, L)

            t = z
            if self.prenorm:
                # Prenorm
                t = norm(t.transpose(-1, -2)).transpose(-1, -2)

            # Apply S4 block: we ignore the state input and output
            #print(z.shape)
            t, _ = layer(t)

            # Dropout on the output of the S4 block
            t = dropout(t)

            # Residual connection
            z = t + z

            if not self.prenorm:
                # Postnorm
                z = norm(z.transpose(-1, -2)).transpose(-1, -2)

        z = z.transpose(-1, -2)

        # Decode the outputs
        #print(x.shape)
        x_hat = self.decoder(z)  # (B, d_model) -> (B, d_output)

        return x_hat, mu, logvar
    
    @staticmethod
    def loss_function(x_hat, x, mu, logvar):
        """
        Loss function 
        """
        KL_loss = 1 + logvar - mu**2 - torch.exp(logvar)
        KL_loss = -0.5 * KL_loss.sum()
        reconstruction_loss = nn.functional.binary_cross_entropy(x_hat, x, reduction='sum')
        loss = reconstruction_loss + KL_loss
        loss = loss/mu.shape[0]

        return loss
    
    @staticmethod
    def reparametrize(mu, logvar):
        # TODO:
        std = torch.sqrt(torch.exp(logvar))
        eps = torch.rand_like(mu)
        z = mu + (std * eps)
        
        return z

# %%
print('==> Building generator..')
vae = VAE_SSM(d_input=1,
d_output=784,
d_model=256,
n_layers=6,
dropout=0.2,
prenorm=False,
).to(device)

N, in_channels, H, W = 8, 3, 64, 64
noise_dim = 100
x = torch.randn((256, 784, 1)).to(device)
x_hat, mu, logvar = vae(x)
print("X_hat", x_hat.shape)
# Out:
# ==> Building generator..
# X_hat torch.Size([256, 784, 1])

# %%
n_epochs = 10
batch_size = 32

transforms = transforms.Compose([
        #transforms.Resize(IMAGE_SIZE),
        transforms.ToTensor(),
        transforms.Lambda(lambda x: x.view(1, 784).t())
    ])

#LOAD MNIST
dataset = datasets.MNIST(root="dataset/", train=True, transform=transforms, download=True)

dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

test_dataset = datasets.MNIST(root="dataset/", train=False, transform=transforms, download=True)


test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True)

# %%
optimizer = torch.optim.Adam(vae.parameters(), lr = 0.001) 
for epoch in range(n_epochs):
    vae.train()
    train_loss = 0
    loss = None
    for data, labels in dataloader:
        #TODO
        data = data.to(device)
        #data = data / 255.0
        optimizer.zero_grad() # clear the gradients of all optimized variables
        output, mu, logvar = vae(x = data) # forward pass:
        #print(data.shape)
        data = data.reshape(data.shape[0], 1, 28, 28)
        output = output.reshape(output.shape[0], 1, 28, 28)
        loss = VAE_SSM.loss_function(output, data, mu, logvar) # calculate the loss using the loss function defined above
        loss.backward() # backward pass: compute gradient of the loss with respect to model parameters
        optimizer.step() # perform a single optimization step (parameter update)
        train_loss += loss.item() # update running training loss
    train_loss = train_loss/len(dataloader)
    print('Epoch: {} \tTraining Loss: {:.6f}'.format(epoch, train_loss))
# Out:
# Epoch: 0 	Training Loss: 428.879854
# Epoch: 1 	Training Loss: 87.411662
# Epoch: 2 	Training Loss: 80.192251
# Epoch: 3 	Training Loss: 77.184745
# Epoch: 4 	Training Loss: 75.326919
# Epoch: 5 	Training Loss: 74.068720
# Epoch: 6 	Training Loss: 73.062171
# Epoch: 7 	Training Loss: 72.437405
# Epoch: 8 	Training Loss: 71.737173
# Epoch: 9 	Training Loss: 71.424468

# %%
def visualize_img_batch(image_batch): # shape of the image batch should be (N, H, W)
    #print(image_batch.shape)
    img_num, H, W = image_batch.shape
    vis_w = 10
    vis_h = int(np.ceil(img_num/10))

    padded_img_num = vis_w*vis_h
    
    if padded_img_num != img_num:
        empty_img_num = padded_img_num - img_num
        padded_image_batch = np.concatenate([image_batch, np.ones( (empty_img_num, H, W))], axis = 0 )
    else:
        padded_image_batch = image_batch
    
    padded_image_batch = np.stack([np.pad(img,(1,1), 'constant', constant_values=(1,1)) for img in padded_image_batch], axis = 0) 
    padded_image_batch = np.reshape(padded_image_batch, (vis_h, vis_w, H+2, W+2 ))
    padded_image_batch = np.concatenate( padded_image_batch, axis=1)
    padded_image_batch = np.concatenate( padded_image_batch, axis=1)
    
    fig = plt.figure(figsize=(vis_w,vis_h))
    plt.imshow(padded_image_batch, cmap='gray')
    plt.axis('off')

# %%
images = next(iter(test_dataloader))[0][0:10,:,:].to(device)
visualize_img_batch(images.reshape(10, 1, 28, 28).detach().cpu().numpy().squeeze())
print(images.shape)
images = images.repeat(10,1,1).to(device)
print(images.shape)
out, _, _ = vae(images)
out = out.transpose(-1, -2)
out = out.reshape(100, 1, 28, 28)
visualize_img_batch(out.detach().cpu().numpy().squeeze())
# Out:
# torch.Size([10, 784, 1])
# torch.Size([100, 784, 1])

# %%
torch.save(vae.state_dict(), 'mnist_s4vae_enc_dec.pth')
print("Save successful!")
# Out:
# Save successful!

# %%
#FID Score
from evaluation_metrics import fid_score, PartialInceptionNetwork
transforms = transforms.Compose([
        #transforms.Resize(IMAGE_SIZE),
        transforms.ToTensor(),
        transforms.Lambda(lambda x: x.view(1, 784).t())
    ])
test_dataset = datasets.MNIST(root="dataset/", train=False, transform=transforms, download=True)
test_dataloader = DataLoader(test_dataset, batch_size=256, shuffle=True)
'''vae = VAE_SSM(d_input=1,
d_output=784,
d_model=256,
n_layers=6,
dropout=0.2,
prenorm=False,
).to(device)'''

#this is only for one particular batch --- Calculation of FID
dataiter = iter(test_dataloader)
images, labels = next(dataiter)

def detransform_torch(transformed_batch):
    original_image = transformed_batch.unsqueeze(0) 
    original_image = original_image.view(transformed_batch.shape[0], 1, 28, 28)
    return original_image
'''in_images = detransform_torch(images)
in_images = in_images.repeat(1, 3, 1, 1)
real_images = F.interpolate(in_images, size = (299, 299))
out, _, _ = vae(images.to(device))
out_img = detransform_torch(out)
out_img = out_img.repeat(1, 3, 1, 1)
gen_images = F.interpolate(out_img, size = (299, 299))

model = PartialInceptionNetwork().to(device)
fid_score = fid_score(real_images, gen_images, 32, model)
print("FID Score:", fid_score)'''
# Out:
# 'in_images = detransform_torch(images)\nin_images = in_images.repeat(1, 3, 1, 1)\nreal_images = F.interpolate(in_images, size = (299, 299))\nout, _, _ = vae(images.to(device))\nout_img = detransform_torch(out)\nout_img = out_img.repeat(1, 3, 1, 1)\ngen_images = F.interpolate(out_img, size = (299, 299))\n\nmodel = PartialInceptionNetwork().to(device)\nfid_score = fid_score(real_images, gen_images, 32, model)\nprint("FID Score:", fid_score)'

# %%
from evaluation_metrics import fid_score, PartialInceptionNetwork
model = PartialInceptionNetwork()


FID_Score = 0
vae = VAE_SSM(d_input=1,
d_output=784,
d_model=256,
n_layers=6,
dropout=0.2,
prenorm=False,
).to(device)
vae.load_state_dict(torch.load('mnist_s4vae_enc_dec.pth', map_location=device))
vae.eval()
i=0
with torch.no_grad():
    for inputs, labels in test_dataloader:
        in_images = detransform_torch(inputs)
        in_images = in_images.repeat(1,3,1,1)
        real_images = F.interpolate(in_images, size = (299,299))

        #output
        out, _, _ = vae(inputs.to(device))
        out_img = detransform_torch(out)
        out_img = out_img.repeat(1,3,1,1)
        gen_images = F.interpolate(out_img, size = (299,299))
        #print(inputs.shape[0])
        fid_score_batch = fid_score(real_images, gen_images, inputs.shape[0], model)
        FID_Score += fid_score_batch
        print(f"{i}th batch has completed and the FID Score for this batch is {fid_score_batch}")
        i+=1
print("FID Score: ", FID_Score/len(test_dataloader))
# Out:
# /home/abadagab/anaconda3/envs/S4gan/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/abadagab/anaconda3/envs/S4gan/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=Inception_V3_Weights.IMAGENET1K_V1`. You can also use `weights=Inception_V3_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# 0th batch has completed and the FID Score for this batch is 21.395373094478515
# 1th batch has completed and the FID Score for this batch is 21.41644797373786
# 2th batch has completed and the FID Score for this batch is 22.034486437431013
# 3th batch has completed and the FID Score for this batch is 22.38968128299581
# 4th batch has completed and the FID Score for this batch is 21.59128234406245
# 5th batch has completed and the FID Score for this batch is 20.96833134860023
# 6th batch has completed and the FID Score for this batch is 21.457774554279183
# 7th batch has completed and the FID Score for this batch is 22.462457708523914
# 8th batch has completed and the FID Score for this batch is 20.616336443409807
# 9th batch has completed and the FID Score for this batch is 22.037156121421845
# 10th batch has completed and the FID Score for this batch is 21.036228338270092
# 11th batch has completed and the FID Score for this batch is 21.398189080808464
# 12th batch has completed and the FID Score for this batch is 21.668640868664028
# 13th batch has completed and the FID Score for this batch is 21.526261198884725
# 14th batch has completed and the FID Score for this batch is 22.083930234952902
# 15th batch has completed and the FID Score for this batch is 21.47149069242539
# 16th batch has completed and the FID Score for this batch is 21.828226818291768
# 17th batch has completed and the FID Score for this batch is 22.94167121563902
# 18th batch has completed and the FID Score for this batch is 22.16907877885444
# 19th batch has completed and the FID Score for this batch is 19.90396723581901
# 20th batch has completed and the FID Score for this batch is 21.53032541566776
# 21th batch has completed and the FID Score for this batch is 21.285853533661026
# 22th batch has completed and the FID Score for this batch is 21.089827926144835
# 23th batch has completed and the FID Score for this batch is 21.455183569288437
# 24th batch has completed and the FID Score for this batch is 22.923853213859843
# 25th batch has completed and the FID Score for this batch is 21.34742899873325
# 26th batch has completed and the FID Score for this batch is 21.41654187091666
# 27th batch has completed and the FID Score for this batch is 21.17316678496121
# 28th batch has completed and the FID Score for this batch is 22.279456432844654
# 29th batch has completed and the FID Score for this batch is 21.774988081811614
# 30th batch has completed and the FID Score for this batch is 22.03312656868289
# 31th batch has completed and the FID Score for this batch is 22.163495138886532
# 32th batch has completed and the FID Score for this batch is 21.277239505976752
# 33th batch has completed and the FID Score for this batch is 21.696857566444464
# 34th batch has completed and the FID Score for this batch is 21.570883806642144
# 35th batch has completed and the FID Score for this batch is 21.204431616188202
# 36th batch has completed and the FID Score for this batch is 20.664533393303344
# 37th batch has completed and the FID Score for this batch is 21.64659207420351
# 38th batch has completed and the FID Score for this batch is 20.575670582096507
# 39th batch has completed and the FID Score for this batch is 52.38556602493901
# FID Score:  22.34730084692008
